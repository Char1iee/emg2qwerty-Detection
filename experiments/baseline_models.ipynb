# %% [markdown]
# # Architecture Experiment:
#
# Architectures compared here:
# - `tds_conv_ctc` (baseline)
# - `recurrent_lstm_ctc`
# - `recurrent_gru_ctc`
# - `recurrent_rnn_ctc`

# %%
from pathlib import Path
import os

CANDIDATES = [
    Path('/content/drive/MyDrive/emg2qwerty'),
    Path('/content/emg2qwerty'),
    Path('/Users/byte/Library/CloudStorage/GoogleDrive-zijiezh@g.ucla.edu/My Drive/emg2qwerty'),
]

REPO = next((p for p in CANDIDATES if p.exists()), None)
if REPO is None:
    raise FileNotFoundError(
        'Could not find repo. Checked:\n'
        + '\n'.join(str(p) for p in CANDIDATES)
        + '\n\nIf running in Colab, mount Drive first and verify folder name.'
    )

os.chdir(REPO)
print('Working directory:', Path.cwd())
print('Logs dir:', REPO / 'logs')
# Out:
# Working directory: c:\Users\Charlie Shang\OneDrive\桌面\学习相关\C247A\emg2qwerty-Detection
# Logs dir: c:\Users\Charlie Shang\OneDrive\桌面\学习相关\C247A\emg2qwerty-Detection\logs

# %%
import importlib
import sys

required = [
    'hydra',
    'pytorch_lightning',
    'torch',
    'tensorboard',
]

missing = [pkg for pkg in required if importlib.util.find_spec(pkg) is None]
print('Python:', sys.executable)
if missing:
    print('Missing packages:', missing)
    print('Install with: pip install -r requirements.txt && pip install -e .')
else:
    print('All required packages found.')
# Out:
# Python: /usr/bin/python3
# All required packages found.

# %%
import os
import subprocess
import sys
from pathlib import Path
import time
from collections import deque

import yaml

requested_models = [
    'tds_conv_ctc',
    'recurrent_lstm_ctc',
    'recurrent_gru_ctc',
    'recurrent_rnn_ctc',
]
MODELS = [m for m in requested_models if (REPO / 'config' / 'model' / f'{m}.yaml').exists()]
missing_models = sorted(set(requested_models) - set(MODELS))
print('Models to run:', MODELS)
if missing_models:
    print('Skipping missing model configs:', missing_models)


def has_gpu() -> bool:
    try:
        import torch
        return bool(torch.cuda.is_available())
    except Exception:
        return False


def preflight_data_check() -> None:
    cfg_path = REPO / 'config' / 'user' / 'single_user.yaml'
    data_root = REPO / 'data'
    if not cfg_path.exists():
        raise FileNotFoundError(f'Missing user split config: {cfg_path}')
    if not data_root.exists():
        raise FileNotFoundError(f'Missing data directory: {data_root}')

    cfg = yaml.safe_load(cfg_path.read_text())
    missing = []
    for split in ['train', 'val', 'test']:
        for item in cfg['dataset'][split]:
            session = item['session']
            hdf5_path = data_root / f'{session}.hdf5'
            if not hdf5_path.exists():
                missing.append(hdf5_path)

    if missing:
        preview = '\n'.join(str(p) for p in missing[:10])
        raise FileNotFoundError(
            f'Missing {len(missing)} data files under {data_root}. First 10:\n{preview}'
        )

    print('Preflight data check passed.')


accelerator = 'gpu' if has_gpu() else 'cpu'
MAX_EPOCHS = 40
AUTO_FALLBACK_TO_CPU = True

print('Using accelerator:', accelerator)
print('Max epochs per model:', MAX_EPOCHS)
preflight_data_check()


def run_dir_for(model_name: str, accel: str) -> Path:
    return REPO / 'logs' / 'architecture_experiment' / 'runs' / f'{model_name}_{accel}'


def build_args(model_name: str, accel: str):
    run_dir = run_dir_for(model_name, accel)
    return [
        'user=single_user',
        f'trainer.accelerator={accel}',
        'trainer.devices=1',
        f'trainer.max_epochs={MAX_EPOCHS}',
        '+trainer.enable_progress_bar=true',
        f'hydra.run.dir={run_dir}',
        'num_workers=0',
    ]


def run_with_live_output(cmd, log_file: Path):
    tail = deque(maxlen=120)
    env = os.environ.copy()
    env['HYDRA_FULL_ERROR'] = '1'

    log_file.parent.mkdir(parents=True, exist_ok=True)
    with log_file.open('w', encoding='utf-8') as lf:
        proc = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1,
            env=env,
        )
        assert proc.stdout is not None
        for line in proc.stdout:
            print(line, end='')
            lf.write(line)
            tail.append(line.rstrip('\n'))

        ret = proc.wait()

    if ret != 0:
        print(f'\nFull log saved to: {log_file}')
        print('\n----- Last 120 log lines -----')
        print('\n'.join(tail))
        raise RuntimeError(f'Command failed with exit code {ret}')


def run_model(model_name: str, accel: str):
    run_dir = run_dir_for(model_name, accel)
    last_ckpt = run_dir / 'checkpoints' / 'last.ckpt'
    if last_ckpt.exists():
        print(f'Resuming from existing checkpoint: {last_ckpt}')

    cmd = [
        sys.executable,
        '-m',
        'emg2qwerty.train',
        f'model={model_name}',
        *build_args(model_name, accel),
    ]
    print('\nRunning:', ' '.join(cmd), flush=True)

    start = time.time()
    log_file = REPO / 'logs' / 'architecture_experiment' / f'{model_name}_{accel}.log'
    run_with_live_output(cmd, log_file=log_file)
    elapsed_min = (time.time() - start) / 60.0
    print(f'{model_name} completed successfully on {accel} in {elapsed_min:.1f} min.')


for i, model_name in enumerate(MODELS, start=1):
    print(f'\n===== Model {i}/{len(MODELS)}: {model_name} =====', flush=True)
    try:
        run_model(model_name, accelerator)
    except Exception as e:
        if accelerator == 'gpu' and AUTO_FALLBACK_TO_CPU:
            print(f'\nGPU run failed for {model_name}: {e}')
            print('Retrying once on CPU...')
            run_model(model_name, 'cpu')
        else:
            raise

print('\nAll architecture runs completed.')
# Out:
# Models to run: ['tds_conv_ctc', 'recurrent_lstm_ctc', 'recurrent_rnn_ctc']
# Skipping missing model configs: ['recurrent_gru_ctc']
# Using accelerator: gpu
# Max epochs per model: 40
# Preflight data check passed.
#
# ===== Model 1/3: tds_conv_ctc =====
#
# Running: /usr/bin/python3 -m emg2qwerty.train model=tds_conv_ctc user=single_user trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=40 +trainer.enable_progress_bar=true hydra.run.dir=/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu num_workers=0
# [2026-03-06 01:23:40,614][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 0
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 40
#   default_root_dir: ${hydra:runtime.output_dir}
#   enable_progress_bar: true
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# Global seed set to 1501
# [2026-03-06 01:23:40,620][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2026-03-06 01:23:40,779][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /usr/local/lib/python3.12/dist-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# /usr/local/lib/python3.12/dist-packages/matplotlib/_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#   ParserElement.enablePackrat()
# [2026-03-06 01:23:42,968][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'parseString' deprecated - use 'parse_string'
# [2026-03-06 01:23:42,969][matplotlib.style.core][WARNING] - In /usr/local/lib/python3.12/dist-packages/matplotlib/mpl-data/stylelib/classic.mplstyle: 'resetCache' deprecated - use 'reset_cache'
# /usr/local/lib/python3.12/dist-packages/hydra/_internal/instantiate/_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 5.3 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 5.3 M     Trainable params
# 0         Non-trainable params
# 5.3 M     Total params
# 21.173    Total estimated model params size (MB)
#
# Sanity Checking: 0it [00:00, ?it/s]/usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
#
# Sanity Checking:   0%|          | 0/2 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  2.85it/s]
#                                                                            /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
#
#
# Training: 0it [00:00, ?it/s]
# Training:   0%|          | 0/127 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/127 [00:00<?, ?it/s]
# Epoch 0:  16%|█▌        | 20/127 [00:12<01:07,  1.59it/s]
# Epoch 0:  16%|█▌        | 20/127 [00:12<01:07,  1.59it/s, loss=120, v_num=0]
# Epoch 0:  31%|███▏      | 40/127 [00:23<00:51,  1.69it/s, loss=120, v_num=0]
# Epoch 0:  31%|███▏      | 40/127 [00:23<00:51,  1.68it/s, loss=127, v_num=0]
# Epoch 0:  47%|████▋     | 60/127 [00:34<00:38,  1.73it/s, loss=127, v_num=0]
# Epoch 0:  47%|████▋     | 60/127 [00:34<00:38,  1.73it/s, loss=125, v_num=0]
# Epoch 0:  63%|██████▎   | 80/127 [00:45<00:26,  1.76it/s, loss=125, v_num=0]
# Epoch 0:  63%|██████▎   | 80/127 [00:45<00:26,  1.76it/s, loss=123, v_num=0]
# Epoch 0:  79%|███████▊  | 100/127 [00:58<00:15,  1.71it/s, loss=123, v_num=0]
# Epoch 0:  79%|███████▊  | 100/127 [00:58<00:15,  1.71it/s, loss=137, v_num=0]
# Epoch 0:  94%|█████████▍| 120/127 [01:08<00:03,  1.76it/s, loss=137, v_num=0]
# Epoch 0:  94%|█████████▍| 120/127 [01:08<00:03,  1.76it/s, loss=116, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  2.96it/s]
# Epoch 0: 100%|██████████| 127/127 [01:10<00:00,  1.80it/s, loss=116, v_num=0]
# Epoch 0: 100%|██████████| 127/127 [01:10<00:00,  1.80it/s, loss=116, v_num=0]
#
#
# Epoch 0: 100%|██████████| 127/127 [01:10<00:00,  1.80it/s, loss=116, v_num=0]Epoch 0, global step 120: 'val/CER' reached 1355.78198 (best 1355.78198), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=0-step=120.ckpt' as top 1
#
# Epoch 0:   0%|          | 0/127 [00:00<?, ?it/s, loss=116, v_num=0]
# Epoch 1:   0%|          | 0/127 [00:00<?, ?it/s, loss=116, v_num=0]
# Epoch 1:  16%|█▌        | 20/127 [00:08<00:46,  2.31it/s, loss=116, v_num=0]
# Epoch 1:  16%|█▌        | 20/127 [00:08<00:46,  2.30it/s, loss=32.9, v_num=0]
# Epoch 1:  31%|███▏      | 40/127 [00:18<00:39,  2.19it/s, loss=32.9, v_num=0]
# Epoch 1:  31%|███▏      | 40/127 [00:18<00:39,  2.18it/s, loss=6.25, v_num=0]
# Epoch 1:  47%|████▋     | 60/127 [00:27<00:30,  2.18it/s, loss=6.25, v_num=0]
# Epoch 1:  47%|████▋     | 60/127 [00:27<00:30,  2.17it/s, loss=4.02, v_num=0]
# Epoch 1:  63%|██████▎   | 80/127 [00:35<00:21,  2.23it/s, loss=4.02, v_num=0]
# Epoch 1:  63%|██████▎   | 80/127 [00:35<00:21,  2.23it/s, loss=3.67, v_num=0]
# Epoch 1:  79%|███████▊  | 100/127 [00:45<00:12,  2.22it/s, loss=3.67, v_num=0]
# Epoch 1:  79%|███████▊  | 100/127 [00:45<00:12,  2.21it/s, loss=3.53, v_num=0]
# Epoch 1:  94%|█████████▍| 120/127 [00:54<00:03,  2.21it/s, loss=3.53, v_num=0]
# Epoch 1:  94%|█████████▍| 120/127 [00:54<00:03,  2.21it/s, loss=3.47, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  3.10it/s]
# Epoch 1: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=3.47, v_num=0]
# Epoch 1: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=3.47, v_num=0]
#
#
# Epoch 1: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=3.47, v_num=0]Epoch 1, global step 240: 'val/CER' reached 100.00000 (best 100.00000), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=1-step=240.ckpt' as top 1
#
# Epoch 1:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.47, v_num=0]
# Epoch 2:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.47, v_num=0]
# Epoch 2:  16%|█▌        | 20/127 [00:08<00:45,  2.33it/s, loss=3.47, v_num=0]
# Epoch 2:  16%|█▌        | 20/127 [00:08<00:46,  2.32it/s, loss=3.47, v_num=0]
# Epoch 2:  31%|███▏      | 40/127 [00:17<00:38,  2.23it/s, loss=3.47, v_num=0]
# Epoch 2:  31%|███▏      | 40/127 [00:17<00:39,  2.23it/s, loss=3.41, v_num=0]
# Epoch 2:  47%|████▋     | 60/127 [00:27<00:30,  2.20it/s, loss=3.41, v_num=0]
# Epoch 2:  47%|████▋     | 60/127 [00:27<00:30,  2.19it/s, loss=3.33, v_num=0]
# Epoch 2:  63%|██████▎   | 80/127 [00:35<00:20,  2.26it/s, loss=3.33, v_num=0]
# Epoch 2:  63%|██████▎   | 80/127 [00:35<00:20,  2.26it/s, loss=3.41, v_num=0]
# Epoch 2:  79%|███████▊  | 100/127 [00:44<00:11,  2.26it/s, loss=3.41, v_num=0]
# Epoch 2:  79%|███████▊  | 100/127 [00:44<00:11,  2.25it/s, loss=3.32, v_num=0]
# Epoch 2:  94%|█████████▍| 120/127 [00:53<00:03,  2.24it/s, loss=3.32, v_num=0]
# Epoch 2:  94%|█████████▍| 120/127 [00:53<00:03,  2.24it/s, loss=3.38, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.87it/s]
# Epoch 2: 100%|██████████| 127/127 [00:55<00:00,  2.29it/s, loss=3.38, v_num=0]
# Epoch 2: 100%|██████████| 127/127 [00:55<00:00,  2.29it/s, loss=3.38, v_num=0]
#
#
# Epoch 2: 100%|██████████| 127/127 [00:55<00:00,  2.29it/s, loss=3.38, v_num=0]Epoch 2, global step 360: 'val/CER' was not in top 1
#
# Epoch 2:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.38, v_num=0]
# Epoch 3:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.38, v_num=0]
# Epoch 3:  16%|█▌        | 20/127 [00:08<00:44,  2.41it/s, loss=3.38, v_num=0]
# Epoch 3:  16%|█▌        | 20/127 [00:08<00:44,  2.40it/s, loss=3.33, v_num=0]
# Epoch 3:  31%|███▏      | 40/127 [00:19<00:41,  2.10it/s, loss=3.33, v_num=0]
# Epoch 3:  31%|███▏      | 40/127 [00:19<00:41,  2.10it/s, loss=3.24, v_num=0]
# Epoch 3:  47%|████▋     | 60/127 [00:28<00:31,  2.13it/s, loss=3.24, v_num=0]
# Epoch 3:  47%|████▋     | 60/127 [00:28<00:31,  2.13it/s, loss=3.24, v_num=0]
# Epoch 3:  63%|██████▎   | 80/127 [00:37<00:21,  2.15it/s, loss=3.24, v_num=0]
# Epoch 3:  63%|██████▎   | 80/127 [00:37<00:21,  2.14it/s, loss=3.31, v_num=0]
# Epoch 3:  79%|███████▊  | 100/127 [00:45<00:12,  2.19it/s, loss=3.31, v_num=0]
# Epoch 3:  79%|███████▊  | 100/127 [00:45<00:12,  2.19it/s, loss=3.23, v_num=0]
# Epoch 3:  94%|█████████▍| 120/127 [00:54<00:03,  2.19it/s, loss=3.23, v_num=0]
# Epoch 3:  94%|█████████▍| 120/127 [00:54<00:03,  2.19it/s, loss=3.25, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.00it/s]
# Epoch 3: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=3.25, v_num=0]
# Epoch 3: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=3.25, v_num=0]
#
#
# Epoch 3: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=3.25, v_num=0]Epoch 3, global step 480: 'val/CER' was not in top 1
#
# Epoch 3:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.25, v_num=0]
# Epoch 4:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.25, v_num=0]
# Epoch 4:  16%|█▌        | 20/127 [00:09<00:49,  2.14it/s, loss=3.25, v_num=0]
# Epoch 4:  16%|█▌        | 20/127 [00:09<00:50,  2.13it/s, loss=3.19, v_num=0]
# Epoch 4:  31%|███▏      | 40/127 [00:17<00:38,  2.25it/s, loss=3.19, v_num=0]
# Epoch 4:  31%|███▏      | 40/127 [00:17<00:38,  2.24it/s, loss=3.23, v_num=0]
# Epoch 4:  47%|████▋     | 60/127 [00:28<00:31,  2.10it/s, loss=3.23, v_num=0]
# Epoch 4:  47%|████▋     | 60/127 [00:28<00:31,  2.10it/s, loss=3.19, v_num=0]
# Epoch 4:  63%|██████▎   | 80/127 [00:37<00:22,  2.13it/s, loss=3.19, v_num=0]
# Epoch 4:  63%|██████▎   | 80/127 [00:37<00:22,  2.12it/s, loss=3.19, v_num=0]
# Epoch 4:  79%|███████▊  | 100/127 [00:46<00:12,  2.14it/s, loss=3.19, v_num=0]
# Epoch 4:  79%|███████▊  | 100/127 [00:46<00:12,  2.14it/s, loss=3.18, v_num=0]
# Epoch 4:  94%|█████████▍| 120/127 [00:55<00:03,  2.18it/s, loss=3.18, v_num=0]
# Epoch 4:  94%|█████████▍| 120/127 [00:55<00:03,  2.18it/s, loss=3.2, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.95it/s]
# Epoch 4: 100%|██████████| 127/127 [00:57<00:00,  2.22it/s, loss=3.2, v_num=0]
# Epoch 4: 100%|██████████| 127/127 [00:57<00:00,  2.22it/s, loss=3.2, v_num=0]
#
#
# Epoch 4: 100%|██████████| 127/127 [00:57<00:00,  2.22it/s, loss=3.2, v_num=0]Epoch 4, global step 600: 'val/CER' was not in top 1
#
# Epoch 4:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.2, v_num=0]
# Epoch 5:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.2, v_num=0]
# Epoch 5:  16%|█▌        | 20/127 [00:09<00:49,  2.16it/s, loss=3.2, v_num=0]
# Epoch 5:  16%|█▌        | 20/127 [00:09<00:49,  2.15it/s, loss=3.14, v_num=0]
# Epoch 5:  31%|███▏      | 40/127 [00:19<00:41,  2.10it/s, loss=3.14, v_num=0]
# Epoch 5:  31%|███▏      | 40/127 [00:19<00:41,  2.09it/s, loss=3.14, v_num=0]
# Epoch 5:  47%|████▋     | 60/127 [00:27<00:30,  2.20it/s, loss=3.14, v_num=0]
# Epoch 5:  47%|████▋     | 60/127 [00:27<00:30,  2.19it/s, loss=3.14, v_num=0]
# Epoch 5:  63%|██████▎   | 80/127 [00:36<00:21,  2.19it/s, loss=3.14, v_num=0]
# Epoch 5:  63%|██████▎   | 80/127 [00:36<00:21,  2.19it/s, loss=3.12, v_num=0]
# Epoch 5:  79%|███████▊  | 100/127 [00:46<00:12,  2.15it/s, loss=3.12, v_num=0]
# Epoch 5:  79%|███████▊  | 100/127 [00:46<00:12,  2.14it/s, loss=3.16, v_num=0]
# Epoch 5:  94%|█████████▍| 120/127 [00:54<00:03,  2.19it/s, loss=3.16, v_num=0]
# Epoch 5:  94%|█████████▍| 120/127 [00:54<00:03,  2.19it/s, loss=3.07, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  2.48it/s]
# Epoch 5: 100%|██████████| 127/127 [00:58<00:00,  2.19it/s, loss=3.07, v_num=0]
# Epoch 5: 100%|██████████| 127/127 [00:58<00:00,  2.19it/s, loss=3.07, v_num=0]
#
#
# Epoch 5: 100%|██████████| 127/127 [00:58<00:00,  2.19it/s, loss=3.07, v_num=0]Epoch 5, global step 720: 'val/CER' was not in top 1
#
# Epoch 5:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.07, v_num=0]
# Epoch 6:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.07, v_num=0]
# Epoch 6:  16%|█▌        | 20/127 [00:08<00:44,  2.42it/s, loss=3.07, v_num=0]
# Epoch 6:  16%|█▌        | 20/127 [00:08<00:44,  2.40it/s, loss=3.11, v_num=0]
# Epoch 6:  31%|███▏      | 40/127 [00:17<00:38,  2.26it/s, loss=3.11, v_num=0]
# Epoch 6:  31%|███▏      | 40/127 [00:17<00:38,  2.25it/s, loss=3.09, v_num=0]
# Epoch 6:  47%|████▋     | 60/127 [00:26<00:29,  2.27it/s, loss=3.09, v_num=0]
# Epoch 6:  47%|████▋     | 60/127 [00:26<00:29,  2.26it/s, loss=3.03, v_num=0]
# Epoch 6:  63%|██████▎   | 80/127 [00:34<00:20,  2.29it/s, loss=3.03, v_num=0]
# Epoch 6:  63%|██████▎   | 80/127 [00:34<00:20,  2.29it/s, loss=3.03, v_num=0]
# Epoch 6:  79%|███████▊  | 100/127 [00:43<00:11,  2.29it/s, loss=3.03, v_num=0]
# Epoch 6:  79%|███████▊  | 100/127 [00:43<00:11,  2.29it/s, loss=3.07, v_num=0]
# Epoch 6:  94%|█████████▍| 120/127 [00:52<00:03,  2.30it/s, loss=3.07, v_num=0]
# Epoch 6:  94%|█████████▍| 120/127 [00:52<00:03,  2.30it/s, loss=3.02, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  3.05it/s]
# Epoch 6: 100%|██████████| 127/127 [00:54<00:00,  2.32it/s, loss=3.02, v_num=0]
# Epoch 6: 100%|██████████| 127/127 [00:54<00:00,  2.32it/s, loss=3.02, v_num=0]
#
#
# Epoch 6: 100%|██████████| 127/127 [00:54<00:00,  2.32it/s, loss=3.02, v_num=0]Epoch 6, global step 840: 'val/CER' was not in top 1
#
# Epoch 6:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.02, v_num=0]
# Epoch 7:   0%|          | 0/127 [00:00<?, ?it/s, loss=3.02, v_num=0]
# Epoch 7:  16%|█▌        | 20/127 [00:09<00:51,  2.08it/s, loss=3.02, v_num=0]
# Epoch 7:  16%|█▌        | 20/127 [00:09<00:51,  2.07it/s, loss=2.98, v_num=0]
# Epoch 7:  31%|███▏      | 40/127 [00:18<00:40,  2.16it/s, loss=2.98, v_num=0]
# Epoch 7:  31%|███▏      | 40/127 [00:18<00:40,  2.15it/s, loss=2.94, v_num=0]
# Epoch 7:  47%|████▋     | 60/127 [00:27<00:30,  2.16it/s, loss=2.94, v_num=0]
# Epoch 7:  47%|████▋     | 60/127 [00:27<00:31,  2.16it/s, loss=2.97, v_num=0]
# Epoch 7:  63%|██████▎   | 80/127 [00:36<00:21,  2.20it/s, loss=2.97, v_num=0]
# Epoch 7:  63%|██████▎   | 80/127 [00:36<00:21,  2.19it/s, loss=2.97, v_num=0]
# Epoch 7:  79%|███████▊  | 100/127 [00:45<00:12,  2.21it/s, loss=2.97, v_num=0]
# Epoch 7:  79%|███████▊  | 100/127 [00:45<00:12,  2.21it/s, loss=3.07, v_num=0]
# Epoch 7:  94%|█████████▍| 120/127 [00:54<00:03,  2.20it/s, loss=3.07, v_num=0]
# Epoch 7:  94%|█████████▍| 120/127 [00:54<00:03,  2.19it/s, loss=2.95, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.95it/s]
# Epoch 7: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=2.95, v_num=0]
# Epoch 7: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=2.95, v_num=0]
#
#
# Epoch 7: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=2.95, v_num=0]Epoch 7, global step 960: 'val/CER' was not in top 1
#
# Epoch 7:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.95, v_num=0]
# Epoch 8:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.95, v_num=0]
# Epoch 8:  16%|█▌        | 20/127 [00:09<00:49,  2.17it/s, loss=2.95, v_num=0]
# Epoch 8:  16%|█▌        | 20/127 [00:09<00:49,  2.15it/s, loss=2.92, v_num=0]
# Epoch 8:  31%|███▏      | 40/127 [00:18<00:39,  2.21it/s, loss=2.92, v_num=0]
# Epoch 8:  31%|███▏      | 40/127 [00:18<00:39,  2.21it/s, loss=2.99, v_num=0]
# Epoch 8:  47%|████▋     | 60/127 [00:28<00:32,  2.09it/s, loss=2.99, v_num=0]
# Epoch 8:  47%|████▋     | 60/127 [00:28<00:32,  2.09it/s, loss=2.87, v_num=0]
# Epoch 8:  63%|██████▎   | 80/127 [00:37<00:22,  2.11it/s, loss=2.87, v_num=0]
# Epoch 8:  63%|██████▎   | 80/127 [00:37<00:22,  2.11it/s, loss=2.86, v_num=0]
# Epoch 8:  79%|███████▊  | 100/127 [00:46<00:12,  2.17it/s, loss=2.86, v_num=0]
# Epoch 8:  79%|███████▊  | 100/127 [00:46<00:12,  2.16it/s, loss=2.98, v_num=0]
# Epoch 8:  94%|█████████▍| 120/127 [00:54<00:03,  2.19it/s, loss=2.98, v_num=0]
# Epoch 8:  94%|█████████▍| 120/127 [00:54<00:03,  2.19it/s, loss=2.9, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.94it/s]
# Epoch 8: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=2.9, v_num=0]
# Epoch 8: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=2.9, v_num=0]
#
#
# Epoch 8: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=2.9, v_num=0]Epoch 8, global step 1080: 'val/CER' was not in top 1
#
# Epoch 8:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.9, v_num=0]
# Epoch 9:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.9, v_num=0]
# Epoch 9:  16%|█▌        | 20/127 [00:09<00:52,  2.04it/s, loss=2.9, v_num=0]
# Epoch 9:  16%|█▌        | 20/127 [00:09<00:52,  2.02it/s, loss=2.84, v_num=0]
# Epoch 9:  31%|███▏      | 40/127 [00:18<00:41,  2.11it/s, loss=2.84, v_num=0]
# Epoch 9:  31%|███▏      | 40/127 [00:19<00:41,  2.10it/s, loss=2.82, v_num=0]
# Epoch 9:  47%|████▋     | 60/127 [00:27<00:30,  2.20it/s, loss=2.82, v_num=0]
# Epoch 9:  47%|████▋     | 60/127 [00:27<00:30,  2.19it/s, loss=2.75, v_num=0]
# Epoch 9:  63%|██████▎   | 80/127 [00:37<00:21,  2.16it/s, loss=2.75, v_num=0]
# Epoch 9:  63%|██████▎   | 80/127 [00:37<00:21,  2.16it/s, loss=2.82, v_num=0]
# Epoch 9:  79%|███████▊  | 100/127 [00:46<00:12,  2.13it/s, loss=2.82, v_num=0]
# Epoch 9:  79%|███████▊  | 100/127 [00:46<00:12,  2.13it/s, loss=2.79, v_num=0]
# Epoch 9:  94%|█████████▍| 120/127 [00:55<00:03,  2.18it/s, loss=2.79, v_num=0]
# Epoch 9:  94%|█████████▍| 120/127 [00:55<00:03,  2.18it/s, loss=2.7, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  3.21it/s]
# Epoch 9: 100%|██████████| 127/127 [00:57<00:00,  2.21it/s, loss=2.7, v_num=0]
# Epoch 9: 100%|██████████| 127/127 [00:57<00:00,  2.21it/s, loss=2.7, v_num=0]
#
#
# Epoch 9: 100%|██████████| 127/127 [00:57<00:00,  2.21it/s, loss=2.7, v_num=0]Epoch 9, global step 1200: 'val/CER' reached 98.80372 (best 98.80372), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=9-step=1200.ckpt' as top 1
#
# Epoch 9:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.7, v_num=0]
# Epoch 10:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.7, v_num=0]
# Epoch 10:  16%|█▌        | 20/127 [00:08<00:46,  2.29it/s, loss=2.7, v_num=0]
# Epoch 10:  16%|█▌        | 20/127 [00:08<00:47,  2.27it/s, loss=2.71, v_num=0]
# Epoch 10:  31%|███▏      | 40/127 [00:18<00:40,  2.16it/s, loss=2.71, v_num=0]
# Epoch 10:  31%|███▏      | 40/127 [00:18<00:40,  2.15it/s, loss=2.66, v_num=0]
# Epoch 10:  47%|████▋     | 60/127 [00:27<00:30,  2.22it/s, loss=2.66, v_num=0]
# Epoch 10:  47%|████▋     | 60/127 [00:27<00:30,  2.21it/s, loss=2.6, v_num=0]
# Epoch 10:  63%|██████▎   | 80/127 [00:35<00:20,  2.24it/s, loss=2.6, v_num=0]
# Epoch 10:  63%|██████▎   | 80/127 [00:35<00:21,  2.24it/s, loss=2.58, v_num=0]
# Epoch 10:  79%|███████▊  | 100/127 [00:45<00:12,  2.22it/s, loss=2.58, v_num=0]
# Epoch 10:  79%|███████▊  | 100/127 [00:45<00:12,  2.22it/s, loss=2.51, v_num=0]
# Epoch 10:  94%|█████████▍| 120/127 [00:54<00:03,  2.21it/s, loss=2.51, v_num=0]
# Epoch 10:  94%|█████████▍| 120/127 [00:54<00:03,  2.21it/s, loss=2.47, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  3.18it/s]
# Epoch 10: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=2.47, v_num=0]
# Epoch 10: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=2.47, v_num=0]
#
#
# Epoch 10: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=2.47, v_num=0]Epoch 10, global step 1320: 'val/CER' reached 96.27824 (best 96.27824), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=10-step=1320.ckpt' as top 1
#
# Epoch 10:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.47, v_num=0]
# Epoch 11:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.47, v_num=0]
# Epoch 11:  16%|█▌        | 20/127 [00:08<00:47,  2.27it/s, loss=2.47, v_num=0]
# Epoch 11:  16%|█▌        | 20/127 [00:08<00:47,  2.26it/s, loss=2.43, v_num=0]
# Epoch 11:  31%|███▏      | 40/127 [00:18<00:39,  2.20it/s, loss=2.43, v_num=0]
# Epoch 11:  31%|███▏      | 40/127 [00:18<00:39,  2.19it/s, loss=2.4, v_num=0]
# Epoch 11:  47%|████▋     | 60/127 [00:27<00:30,  2.18it/s, loss=2.4, v_num=0]
# Epoch 11:  47%|████▋     | 60/127 [00:27<00:30,  2.18it/s, loss=2.4, v_num=0]
# Epoch 11:  63%|██████▎   | 80/127 [00:35<00:21,  2.23it/s, loss=2.4, v_num=0]
# Epoch 11:  63%|██████▎   | 80/127 [00:35<00:21,  2.23it/s, loss=2.37, v_num=0]
# Epoch 11:  79%|███████▊  | 100/127 [00:44<00:12,  2.23it/s, loss=2.37, v_num=0]
# Epoch 11:  79%|███████▊  | 100/127 [00:44<00:12,  2.23it/s, loss=2.35, v_num=0]
# Epoch 11:  94%|█████████▍| 120/127 [00:53<00:03,  2.24it/s, loss=2.35, v_num=0]
# Epoch 11:  94%|█████████▍| 120/127 [00:53<00:03,  2.24it/s, loss=2.36, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.71it/s]
# Epoch 11: 100%|██████████| 127/127 [00:55<00:00,  2.28it/s, loss=2.36, v_num=0]
# Epoch 11: 100%|██████████| 127/127 [00:55<00:00,  2.28it/s, loss=2.36, v_num=0]
#
#
# Epoch 11: 100%|██████████| 127/127 [00:55<00:00,  2.28it/s, loss=2.36, v_num=0]Epoch 11, global step 1440: 'val/CER' reached 88.96766 (best 88.96766), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=11-step=1440.ckpt' as top 1
#
# Epoch 11:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.36, v_num=0]
# Epoch 12:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.36, v_num=0]
# Epoch 12:  16%|█▌        | 20/127 [00:09<00:52,  2.05it/s, loss=2.36, v_num=0]
# Epoch 12:  16%|█▌        | 20/127 [00:09<00:52,  2.03it/s, loss=2.28, v_num=0]
# Epoch 12:  31%|███▏      | 40/127 [00:19<00:42,  2.06it/s, loss=2.28, v_num=0]
# Epoch 12:  31%|███▏      | 40/127 [00:19<00:42,  2.05it/s, loss=2.27, v_num=0]
# Epoch 12:  47%|████▋     | 60/127 [00:29<00:32,  2.06it/s, loss=2.27, v_num=0]
# Epoch 12:  47%|████▋     | 60/127 [00:29<00:32,  2.06it/s, loss=2.29, v_num=0]
# Epoch 12:  63%|██████▎   | 80/127 [00:38<00:22,  2.08it/s, loss=2.29, v_num=0]
# Epoch 12:  63%|██████▎   | 80/127 [00:38<00:22,  2.08it/s, loss=2.22, v_num=0]
# Epoch 12:  79%|███████▊  | 100/127 [00:46<00:12,  2.14it/s, loss=2.22, v_num=0]
# Epoch 12:  79%|███████▊  | 100/127 [00:46<00:12,  2.13it/s, loss=2.19, v_num=0]
# Epoch 12:  94%|█████████▍| 120/127 [00:56<00:03,  2.14it/s, loss=2.19, v_num=0]
# Epoch 12:  94%|█████████▍| 120/127 [00:56<00:03,  2.14it/s, loss=2.15, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.98it/s]
# Epoch 12: 100%|██████████| 127/127 [00:58<00:00,  2.19it/s, loss=2.15, v_num=0]
# Epoch 12: 100%|██████████| 127/127 [00:58<00:00,  2.19it/s, loss=2.15, v_num=0]
#
#
# Epoch 12: 100%|██████████| 127/127 [00:58<00:00,  2.18it/s, loss=2.15, v_num=0]Epoch 12, global step 1560: 'val/CER' reached 84.66991 (best 84.66991), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=12-step=1560.ckpt' as top 1
#
# Epoch 12:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.15, v_num=0]
# Epoch 13:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.15, v_num=0]
# Epoch 13:  16%|█▌        | 20/127 [00:09<00:52,  2.02it/s, loss=2.15, v_num=0]
# Epoch 13:  16%|█▌        | 20/127 [00:09<00:53,  2.01it/s, loss=2.13, v_num=0]
# Epoch 13:  31%|███▏      | 40/127 [00:19<00:41,  2.08it/s, loss=2.13, v_num=0]
# Epoch 13:  31%|███▏      | 40/127 [00:19<00:42,  2.07it/s, loss=2.14, v_num=0]
# Epoch 13:  47%|████▋     | 60/127 [00:27<00:31,  2.16it/s, loss=2.14, v_num=0]
# Epoch 13:  47%|████▋     | 60/127 [00:27<00:31,  2.15it/s, loss=2.13, v_num=0]
# Epoch 13:  63%|██████▎   | 80/127 [00:38<00:22,  2.08it/s, loss=2.13, v_num=0]
# Epoch 13:  63%|██████▎   | 80/127 [00:38<00:22,  2.08it/s, loss=2.07, v_num=0]
# Epoch 13:  79%|███████▊  | 100/127 [00:48<00:12,  2.08it/s, loss=2.07, v_num=0]
# Epoch 13:  79%|███████▊  | 100/127 [00:48<00:13,  2.08it/s, loss=2.06, v_num=0]
# Epoch 13:  94%|█████████▍| 120/127 [00:56<00:03,  2.13it/s, loss=2.06, v_num=0]
# Epoch 13:  94%|█████████▍| 120/127 [00:56<00:03,  2.13it/s, loss=2.05, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  2.89it/s]
# Epoch 13: 100%|██████████| 127/127 [00:58<00:00,  2.16it/s, loss=2.05, v_num=0]
# Epoch 13: 100%|██████████| 127/127 [00:58<00:00,  2.15it/s, loss=2.05, v_num=0]
#
#
# Epoch 13: 100%|██████████| 127/127 [00:58<00:00,  2.15it/s, loss=2.05, v_num=0]Epoch 13, global step 1680: 'val/CER' reached 81.43553 (best 81.43553), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=13-step=1680.ckpt' as top 1
#
# Epoch 13:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.05, v_num=0]
# Epoch 14:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.05, v_num=0]
# Epoch 14:  16%|█▌        | 20/127 [00:08<00:46,  2.28it/s, loss=2.05, v_num=0]
# Epoch 14:  16%|█▌        | 20/127 [00:08<00:47,  2.26it/s, loss=2.02, v_num=0]
# Epoch 14:  31%|███▏      | 40/127 [00:18<00:40,  2.17it/s, loss=2.02, v_num=0]
# Epoch 14:  31%|███▏      | 40/127 [00:18<00:40,  2.16it/s, loss=2, v_num=0]
# Epoch 14:  47%|████▋     | 60/127 [00:27<00:31,  2.16it/s, loss=2, v_num=0]
# Epoch 14:  47%|████▋     | 60/127 [00:27<00:31,  2.15it/s, loss=1.99, v_num=0]
# Epoch 14:  63%|██████▎   | 80/127 [00:35<00:21,  2.22it/s, loss=1.99, v_num=0]
# Epoch 14:  63%|██████▎   | 80/127 [00:36<00:21,  2.22it/s, loss=1.96, v_num=0]
# Epoch 14:  79%|███████▊  | 100/127 [00:46<00:12,  2.15it/s, loss=1.96, v_num=0]
# Epoch 14:  79%|███████▊  | 100/127 [00:46<00:12,  2.15it/s, loss=1.9, v_num=0]
# Epoch 14:  94%|█████████▍| 120/127 [00:55<00:03,  2.16it/s, loss=1.9, v_num=0]
# Epoch 14:  94%|█████████▍| 120/127 [00:55<00:03,  2.16it/s, loss=1.93, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.81it/s]
# Epoch 14: 100%|██████████| 127/127 [00:57<00:00,  2.20it/s, loss=1.93, v_num=0]
# Epoch 14: 100%|██████████| 127/127 [00:57<00:00,  2.20it/s, loss=1.93, v_num=0]
#
#
# Epoch 14: 100%|██████████| 127/127 [00:57<00:00,  2.20it/s, loss=1.93, v_num=0]Epoch 14, global step 1800: 'val/CER' reached 79.57465 (best 79.57465), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=14-step=1800.ckpt' as top 1
#
# Epoch 14:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.93, v_num=0]
# Epoch 15:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.93, v_num=0]
# Epoch 15:  16%|█▌        | 20/127 [00:08<00:47,  2.27it/s, loss=1.93, v_num=0]
# Epoch 15:  16%|█▌        | 20/127 [00:08<00:47,  2.25it/s, loss=1.88, v_num=0]
# Epoch 15:  31%|███▏      | 40/127 [00:17<00:39,  2.23it/s, loss=1.88, v_num=0]
# Epoch 15:  31%|███▏      | 40/127 [00:18<00:39,  2.22it/s, loss=1.84, v_num=0]
# Epoch 15:  47%|████▋     | 60/127 [00:27<00:30,  2.21it/s, loss=1.84, v_num=0]
# Epoch 15:  47%|████▋     | 60/127 [00:27<00:30,  2.21it/s, loss=1.85, v_num=0]
# Epoch 15:  63%|██████▎   | 80/127 [00:36<00:21,  2.22it/s, loss=1.85, v_num=0]
# Epoch 15:  63%|██████▎   | 80/127 [00:36<00:21,  2.21it/s, loss=1.85, v_num=0]
# Epoch 15:  79%|███████▊  | 100/127 [00:44<00:12,  2.24it/s, loss=1.85, v_num=0]
# Epoch 15:  79%|███████▊  | 100/127 [00:44<00:12,  2.24it/s, loss=1.79, v_num=0]
# Epoch 15:  94%|█████████▍| 120/127 [00:53<00:03,  2.23it/s, loss=1.79, v_num=0]
# Epoch 15:  94%|█████████▍| 120/127 [00:53<00:03,  2.23it/s, loss=1.78, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.81it/s]
# Epoch 15: 100%|██████████| 127/127 [00:55<00:00,  2.27it/s, loss=1.78, v_num=0]
# Epoch 15: 100%|██████████| 127/127 [00:55<00:00,  2.27it/s, loss=1.78, v_num=0]
#
#
# Epoch 15: 100%|██████████| 127/127 [00:55<00:00,  2.27it/s, loss=1.78, v_num=0]Epoch 15, global step 1920: 'val/CER' reached 72.30837 (best 72.30837), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=15-step=1920.ckpt' as top 1
#
# Epoch 15:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.78, v_num=0]
# Epoch 16:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.78, v_num=0]
# Epoch 16:  16%|█▌        | 20/127 [00:10<00:54,  1.97it/s, loss=1.78, v_num=0]
# Epoch 16:  16%|█▌        | 20/127 [00:10<00:54,  1.95it/s, loss=1.74, v_num=0]
# Epoch 16:  31%|███▏      | 40/127 [00:19<00:42,  2.06it/s, loss=1.74, v_num=0]
# Epoch 16:  31%|███▏      | 40/127 [00:19<00:42,  2.05it/s, loss=1.74, v_num=0]
# Epoch 16:  47%|████▋     | 60/127 [00:28<00:31,  2.12it/s, loss=1.74, v_num=0]
# Epoch 16:  47%|████▋     | 60/127 [00:28<00:31,  2.12it/s, loss=1.75, v_num=0]
# Epoch 16:  63%|██████▎   | 80/127 [00:37<00:21,  2.14it/s, loss=1.75, v_num=0]
# Epoch 16:  63%|██████▎   | 80/127 [00:37<00:21,  2.14it/s, loss=1.73, v_num=0]
# Epoch 16:  79%|███████▊  | 100/127 [00:45<00:12,  2.18it/s, loss=1.73, v_num=0]
# Epoch 16:  79%|███████▊  | 100/127 [00:45<00:12,  2.18it/s, loss=1.7, v_num=0]
# Epoch 16:  94%|█████████▍| 120/127 [00:54<00:03,  2.20it/s, loss=1.7, v_num=0]
# Epoch 16:  94%|█████████▍| 120/127 [00:54<00:03,  2.20it/s, loss=1.72, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.62it/s]
# Epoch 16: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=1.72, v_num=0]
# Epoch 16: 100%|██████████| 127/127 [00:56<00:00,  2.24it/s, loss=1.72, v_num=0]
#
#
# Epoch 16: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=1.72, v_num=0]Epoch 16, global step 2040: 'val/CER' reached 70.46965 (best 70.46965), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=16-step=2040.ckpt' as top 1
#
# Epoch 16:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.72, v_num=0]
# Epoch 17:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.72, v_num=0]
# Epoch 17:  16%|█▌        | 20/127 [00:09<00:49,  2.15it/s, loss=1.72, v_num=0]
# Epoch 17:  16%|█▌        | 20/127 [00:09<00:49,  2.14it/s, loss=1.68, v_num=0]
# Epoch 17:  31%|███▏      | 40/127 [00:18<00:41,  2.12it/s, loss=1.68, v_num=0]
# Epoch 17:  31%|███▏      | 40/127 [00:18<00:41,  2.11it/s, loss=1.63, v_num=0]
# Epoch 17:  47%|████▋     | 60/127 [00:28<00:32,  2.08it/s, loss=1.63, v_num=0]
# Epoch 17:  47%|████▋     | 60/127 [00:28<00:32,  2.08it/s, loss=1.66, v_num=0]
# Epoch 17:  63%|██████▎   | 80/127 [00:37<00:22,  2.11it/s, loss=1.66, v_num=0]
# Epoch 17:  63%|██████▎   | 80/127 [00:37<00:22,  2.11it/s, loss=1.7, v_num=0]
# Epoch 17:  79%|███████▊  | 100/127 [00:46<00:12,  2.13it/s, loss=1.7, v_num=0]
# Epoch 17:  79%|███████▊  | 100/127 [00:46<00:12,  2.13it/s, loss=1.65, v_num=0]
# Epoch 17:  94%|█████████▍| 120/127 [00:55<00:03,  2.18it/s, loss=1.65, v_num=0]
# Epoch 17:  94%|█████████▍| 120/127 [00:55<00:03,  2.18it/s, loss=1.6, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  3.03it/s]
# Epoch 17: 100%|██████████| 127/127 [00:57<00:00,  2.20it/s, loss=1.6, v_num=0]
# Epoch 17: 100%|██████████| 127/127 [00:57<00:00,  2.20it/s, loss=1.6, v_num=0]
#
#
# Epoch 17: 100%|██████████| 127/127 [00:57<00:00,  2.20it/s, loss=1.6, v_num=0]Epoch 17, global step 2160: 'val/CER' reached 61.07665 (best 61.07665), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=17-step=2160.ckpt' as top 1
#
# Epoch 17:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.6, v_num=0]
# Epoch 18:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.6, v_num=0]
# Epoch 18:  16%|█▌        | 20/127 [00:08<00:46,  2.32it/s, loss=1.6, v_num=0]
# Epoch 18:  16%|█▌        | 20/127 [00:08<00:46,  2.31it/s, loss=1.55, v_num=0]
# Epoch 18:  31%|███▏      | 40/127 [00:18<00:39,  2.21it/s, loss=1.55, v_num=0]
# Epoch 18:  31%|███▏      | 40/127 [00:18<00:39,  2.20it/s, loss=1.56, v_num=0]
# Epoch 18:  47%|████▋     | 60/127 [00:26<00:29,  2.24it/s, loss=1.56, v_num=0]
# Epoch 18:  47%|████▋     | 60/127 [00:26<00:29,  2.24it/s, loss=1.55, v_num=0]
# Epoch 18:  63%|██████▎   | 80/127 [00:36<00:21,  2.22it/s, loss=1.55, v_num=0]
# Epoch 18:  63%|██████▎   | 80/127 [00:36<00:21,  2.22it/s, loss=1.53, v_num=0]
# Epoch 18:  79%|███████▊  | 100/127 [00:45<00:12,  2.21it/s, loss=1.53, v_num=0]
# Epoch 18:  79%|███████▊  | 100/127 [00:45<00:12,  2.20it/s, loss=1.53, v_num=0]
# Epoch 18:  94%|█████████▍| 120/127 [00:54<00:03,  2.20it/s, loss=1.53, v_num=0]
# Epoch 18:  94%|█████████▍| 120/127 [00:54<00:03,  2.20it/s, loss=1.56, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.56it/s]
# Epoch 18: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=1.56, v_num=0]
# Epoch 18: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=1.56, v_num=0]
#
#
# Epoch 18: 100%|██████████| 127/127 [00:56<00:00,  2.23it/s, loss=1.56, v_num=0]Epoch 18, global step 2280: 'val/CER' reached 56.69030 (best 56.69030), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=18-step=2280.ckpt' as top 1
#
# Epoch 18:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.56, v_num=0]
# Epoch 19:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.56, v_num=0]
# Epoch 19:  16%|█▌        | 20/127 [00:08<00:44,  2.42it/s, loss=1.56, v_num=0]
# Epoch 19:  16%|█▌        | 20/127 [00:08<00:44,  2.41it/s, loss=1.52, v_num=0]
# Epoch 19:  31%|███▏      | 40/127 [00:18<00:39,  2.21it/s, loss=1.52, v_num=0]
# Epoch 19:  31%|███▏      | 40/127 [00:18<00:39,  2.21it/s, loss=1.52, v_num=0]
# Epoch 19:  47%|████▋     | 60/127 [00:27<00:30,  2.19it/s, loss=1.52, v_num=0]
# Epoch 19:  47%|████▋     | 60/127 [00:27<00:30,  2.18it/s, loss=1.48, v_num=0]
# Epoch 19:  63%|██████▎   | 80/127 [00:35<00:20,  2.27it/s, loss=1.48, v_num=0]
# Epoch 19:  63%|██████▎   | 80/127 [00:35<00:20,  2.26it/s, loss=1.49, v_num=0]
# Epoch 19:  79%|███████▊  | 100/127 [00:45<00:12,  2.19it/s, loss=1.49, v_num=0]
# Epoch 19:  79%|███████▊  | 100/127 [00:45<00:12,  2.19it/s, loss=1.44, v_num=0]
# Epoch 19:  94%|█████████▍| 120/127 [00:55<00:03,  2.17it/s, loss=1.44, v_num=0]
# Epoch 19:  94%|█████████▍| 120/127 [00:55<00:03,  2.16it/s, loss=1.43, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.05it/s]
# Epoch 19: 100%|██████████| 127/127 [00:57<00:00,  2.21it/s, loss=1.43, v_num=0]
# Epoch 19: 100%|██████████| 127/127 [00:57<00:00,  2.21it/s, loss=1.43, v_num=0]
#
#
# Epoch 19: 100%|██████████| 127/127 [00:57<00:00,  2.21it/s, loss=1.43, v_num=0]Epoch 19, global step 2400: 'val/CER' reached 47.34160 (best 47.34160), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/tds_conv_ctc_gpu/checkpoints/epoch=19-step=2400.ckpt' as top 1
#
# Epoch 19:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.43, v_num=0]
# Epoch 20:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.43, v_num=0]
# Epoch 20:  16%|█▌        | 20/127 [00:09<00:49,  2.15it/s, loss=1.43, v_num=0]
# Epoch 20:  16%|█▌        | 20/127 [00:09<00:49,  2.14it/s, loss=1.39, v_num=0]
# Epoch 20:  31%|███▏      | 40/127 [00:17<00:38,  2.26it/s, loss=1.39, v_num=0]
# Epoch 20:  31%|███▏      | 40/127 [00:17<00:38,  2.24it/s, loss=1.37, v_num=0]
# Epoch 20:  47%|████▋     | 60/127 [00:26<00:30,  2.22it/s, loss=1.37, v_num=0]
# Epoch 20:  47%|████▋     | 60/127 [00:27<00:30,  2.22it/s, loss=1.34, v_num=0]
# Epoch 20:  63%|██████▎   | 80/127 [00:36<00:21,  2.21it/s, loss=1.34, v_num=0]
# Epoch 20:  63%|██████▎   | 80/127 [00:36<00:21,  2.21it/s, loss=1.37, v_num=0]
# Epoch 20:  79%|███████▊  | 100/127 [00:44<00:12,  2.24it/s, loss=1.37, v_num=0]
# Epoch 20:  79%|███████▊  | 100/127 [00:44<00:12,  2.24it/s, loss=1.32, v_num=0]
# Epoch 20:  94%|█████████▍| 120/127 [00:53<00:03,  2.22it/s, loss=1.32, v_num=0]
# Epoch 20:  94%|█████████▍| 120/127 [00:54<00:03,  2.22it/s, loss=1.3, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:02<00:00,  3.40it/s]
# Epoch 20: 100%|██████████| 127/127 [00:56<00:00,  2.25it/s, loss=1.3, v_num=0]
# Epoch 20: 100%|██████████| 127/127 [00:56<00:00,  2.25it/s, loss=1.3, v_num=0]
#
#
# ...
#
# Epoch 32:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.1, v_num=0]
# Epoch 33:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.1, v_num=0]
# Epoch 33:  16%|█▌        | 20/127 [00:08<00:45,  2.35it/s, loss=2.1, v_num=0]
# Epoch 33:  16%|█▌        | 20/127 [00:08<00:45,  2.35it/s, loss=2.11, v_num=0]
# Epoch 33:  31%|███▏      | 40/127 [00:16<00:36,  2.37it/s, loss=2.11, v_num=0]
# Epoch 33:  31%|███▏      | 40/127 [00:16<00:36,  2.37it/s, loss=2.1, v_num=0]
# Epoch 33:  47%|████▋     | 60/127 [00:24<00:27,  2.41it/s, loss=2.1, v_num=0]
# Epoch 33:  47%|████▋     | 60/127 [00:24<00:27,  2.40it/s, loss=2.08, v_num=0]
# Epoch 33:  63%|██████▎   | 80/127 [00:33<00:19,  2.40it/s, loss=2.08, v_num=0]
# Epoch 33:  63%|██████▎   | 80/127 [00:33<00:19,  2.39it/s, loss=2.12, v_num=0]
# Epoch 33:  79%|███████▊  | 100/127 [00:41<00:11,  2.39it/s, loss=2.12, v_num=0]
# Epoch 33:  79%|███████▊  | 100/127 [00:41<00:11,  2.39it/s, loss=2.1, v_num=0]
# Epoch 33:  94%|█████████▍| 120/127 [00:49<00:02,  2.40it/s, loss=2.1, v_num=0]
# Epoch 33:  94%|█████████▍| 120/127 [00:49<00:02,  2.40it/s, loss=2.11, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.23it/s]
# Epoch 33: 100%|██████████| 127/127 [00:51<00:00,  2.45it/s, loss=2.11, v_num=0]
# Epoch 33: 100%|██████████| 127/127 [00:51<00:00,  2.45it/s, loss=2.11, v_num=0]
#
#
# Epoch 33: 100%|██████████| 127/127 [00:51<00:00,  2.45it/s, loss=2.11, v_num=0]Epoch 33, global step 4080: 'val/CER' reached 84.55915 (best 84.55915), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/recurrent_rnn_ctc_gpu/checkpoints/epoch=33-step=4080.ckpt' as top 1
#
# Epoch 33:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.11, v_num=0]
# Epoch 34:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.11, v_num=0]
# Epoch 34:  16%|█▌        | 20/127 [00:08<00:43,  2.44it/s, loss=2.11, v_num=0]
# Epoch 34:  16%|█▌        | 20/127 [00:08<00:43,  2.43it/s, loss=2.08, v_num=0]
# Epoch 34:  31%|███▏      | 40/127 [00:16<00:36,  2.35it/s, loss=2.08, v_num=0]
# Epoch 34:  31%|███▏      | 40/127 [00:17<00:36,  2.35it/s, loss=2.03, v_num=0]
# Epoch 34:  47%|████▋     | 60/127 [00:25<00:28,  2.38it/s, loss=2.03, v_num=0]
# Epoch 34:  47%|████▋     | 60/127 [00:25<00:28,  2.38it/s, loss=2.06, v_num=0]
# Epoch 34:  63%|██████▎   | 80/127 [00:33<00:19,  2.38it/s, loss=2.06, v_num=0]
# Epoch 34:  63%|██████▎   | 80/127 [00:33<00:19,  2.38it/s, loss=2.08, v_num=0]
# Epoch 34:  79%|███████▊  | 100/127 [00:41<00:11,  2.38it/s, loss=2.08, v_num=0]
# Epoch 34:  79%|███████▊  | 100/127 [00:41<00:11,  2.38it/s, loss=2.06, v_num=0]
# Epoch 34:  94%|█████████▍| 120/127 [00:50<00:02,  2.40it/s, loss=2.06, v_num=0]
# Epoch 34:  94%|█████████▍| 120/127 [00:50<00:02,  2.39it/s, loss=2.04, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.79it/s]
# Epoch 34: 100%|██████████| 127/127 [00:52<00:00,  2.43it/s, loss=2.04, v_num=0]
# Epoch 34: 100%|██████████| 127/127 [00:52<00:00,  2.43it/s, loss=2.04, v_num=0]
#
#
# Epoch 34: 100%|██████████| 127/127 [00:52<00:00,  2.43it/s, loss=2.04, v_num=0]Epoch 34, global step 4200: 'val/CER' reached 82.72043 (best 82.72043), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/recurrent_rnn_ctc_gpu/checkpoints/epoch=34-step=4200.ckpt' as top 1
#
# Epoch 34:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.04, v_num=0]
# Epoch 35:   0%|          | 0/127 [00:00<?, ?it/s, loss=2.04, v_num=0]
# Epoch 35:  16%|█▌        | 20/127 [00:08<00:44,  2.43it/s, loss=2.04, v_num=0]
# Epoch 35:  16%|█▌        | 20/127 [00:08<00:44,  2.42it/s, loss=2.04, v_num=0]
# Epoch 35:  31%|███▏      | 40/127 [00:16<00:36,  2.37it/s, loss=2.04, v_num=0]
# Epoch 35:  31%|███▏      | 40/127 [00:16<00:36,  2.37it/s, loss=2.03, v_num=0]
# Epoch 35:  47%|████▋     | 60/127 [00:25<00:28,  2.34it/s, loss=2.03, v_num=0]
# Epoch 35:  47%|████▋     | 60/127 [00:25<00:28,  2.34it/s, loss=2.01, v_num=0]
# Epoch 35:  63%|██████▎   | 80/127 [00:33<00:19,  2.37it/s, loss=2.01, v_num=0]
# Epoch 35:  63%|██████▎   | 80/127 [00:33<00:19,  2.37it/s, loss=2.04, v_num=0]
# Epoch 35:  79%|███████▊  | 100/127 [00:41<00:11,  2.38it/s, loss=2.04, v_num=0]
# Epoch 35:  79%|███████▊  | 100/127 [00:41<00:11,  2.38it/s, loss=2.03, v_num=0]
# Epoch 35:  94%|█████████▍| 120/127 [00:49<00:02,  2.40it/s, loss=2.03, v_num=0]
# Epoch 35:  94%|█████████▍| 120/127 [00:49<00:02,  2.40it/s, loss=1.98, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.08it/s]
# Epoch 35: 100%|██████████| 127/127 [00:51<00:00,  2.45it/s, loss=1.98, v_num=0]
# Epoch 35: 100%|██████████| 127/127 [00:51<00:00,  2.45it/s, loss=1.98, v_num=0]
#
#
# Epoch 35: 100%|██████████| 127/127 [00:51<00:00,  2.45it/s, loss=1.98, v_num=0]Epoch 35, global step 4320: 'val/CER' reached 81.23615 (best 81.23615), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/recurrent_rnn_ctc_gpu/checkpoints/epoch=35-step=4320.ckpt' as top 1
#
# Epoch 35:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.98, v_num=0]
# Epoch 36:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.98, v_num=0]
# Epoch 36:  16%|█▌        | 20/127 [00:08<00:43,  2.48it/s, loss=1.98, v_num=0]
# Epoch 36:  16%|█▌        | 20/127 [00:08<00:43,  2.48it/s, loss=2.02, v_num=0]
# Epoch 36:  31%|███▏      | 40/127 [00:16<00:36,  2.41it/s, loss=2.02, v_num=0]
# Epoch 36:  31%|███▏      | 40/127 [00:16<00:36,  2.41it/s, loss=2.05, v_num=0]
# Epoch 36:  47%|████▋     | 60/127 [00:24<00:27,  2.41it/s, loss=2.05, v_num=0]
# Epoch 36:  47%|████▋     | 60/127 [00:24<00:27,  2.41it/s, loss=2.03, v_num=0]
# Epoch 36:  63%|██████▎   | 80/127 [00:33<00:19,  2.41it/s, loss=2.03, v_num=0]
# Epoch 36:  63%|██████▎   | 80/127 [00:33<00:19,  2.41it/s, loss=2.01, v_num=0]
# Epoch 36:  79%|███████▊  | 100/127 [00:41<00:11,  2.39it/s, loss=2.01, v_num=0]
# Epoch 36:  79%|███████▊  | 100/127 [00:41<00:11,  2.38it/s, loss=2.01, v_num=0]
# Epoch 36:  94%|█████████▍| 120/127 [00:50<00:02,  2.39it/s, loss=2.01, v_num=0]
# Epoch 36:  94%|█████████▍| 120/127 [00:50<00:02,  2.39it/s, loss=2, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.02it/s]
# Epoch 36: 100%|██████████| 127/127 [00:52<00:00,  2.44it/s, loss=2, v_num=0]
# Epoch 36: 100%|██████████| 127/127 [00:52<00:00,  2.44it/s, loss=2, v_num=0]
#
#
# Epoch 36: 100%|██████████| 127/127 [00:52<00:00,  2.44it/s, loss=2, v_num=0]Epoch 36, global step 4440: 'val/CER' was not in top 1
#
# Epoch 36:   0%|          | 0/127 [00:00<?, ?it/s, loss=2, v_num=0]
# Epoch 37:   0%|          | 0/127 [00:00<?, ?it/s, loss=2, v_num=0]
# Epoch 37:  16%|█▌        | 20/127 [00:08<00:43,  2.44it/s, loss=2, v_num=0]
# Epoch 37:  16%|█▌        | 20/127 [00:08<00:43,  2.44it/s, loss=2.01, v_num=0]
# Epoch 37:  31%|███▏      | 40/127 [00:16<00:36,  2.40it/s, loss=2.01, v_num=0]
# Epoch 37:  31%|███▏      | 40/127 [00:16<00:36,  2.40it/s, loss=1.98, v_num=0]
# Epoch 37:  47%|████▋     | 60/127 [00:25<00:27,  2.40it/s, loss=1.98, v_num=0]
# Epoch 37:  47%|████▋     | 60/127 [00:25<00:27,  2.40it/s, loss=1.97, v_num=0]
# Epoch 37:  63%|██████▎   | 80/127 [00:33<00:19,  2.42it/s, loss=1.97, v_num=0]
# Epoch 37:  63%|██████▎   | 80/127 [00:33<00:19,  2.42it/s, loss=2.01, v_num=0]
# Epoch 37:  79%|███████▊  | 100/127 [00:41<00:11,  2.41it/s, loss=2.01, v_num=0]
# Epoch 37:  79%|███████▊  | 100/127 [00:41<00:11,  2.41it/s, loss=2, v_num=0]
# Epoch 37:  94%|█████████▍| 120/127 [00:50<00:02,  2.38it/s, loss=2, v_num=0]
# Epoch 37:  94%|█████████▍| 120/127 [00:50<00:02,  2.38it/s, loss=1.97, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.24it/s]
# Epoch 37: 100%|██████████| 127/127 [00:52<00:00,  2.43it/s, loss=1.97, v_num=0]
# Epoch 37: 100%|██████████| 127/127 [00:52<00:00,  2.43it/s, loss=1.97, v_num=0]
#
#
# Epoch 37: 100%|██████████| 127/127 [00:52<00:00,  2.43it/s, loss=1.97, v_num=0]Epoch 37, global step 4560: 'val/CER' reached 80.35002 (best 80.35002), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/recurrent_rnn_ctc_gpu/checkpoints/epoch=37-step=4560.ckpt' as top 1
#
# Epoch 37:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.97, v_num=0]
# Epoch 38:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.97, v_num=0]
# Epoch 38:  16%|█▌        | 20/127 [00:08<00:44,  2.43it/s, loss=1.97, v_num=0]
# Epoch 38:  16%|█▌        | 20/127 [00:08<00:44,  2.43it/s, loss=2.02, v_num=0]
# Epoch 38:  31%|███▏      | 40/127 [00:16<00:35,  2.43it/s, loss=2.02, v_num=0]
# Epoch 38:  31%|███▏      | 40/127 [00:16<00:35,  2.43it/s, loss=1.97, v_num=0]
# Epoch 38:  47%|████▋     | 60/127 [00:24<00:27,  2.42it/s, loss=1.97, v_num=0]
# Epoch 38:  47%|████▋     | 60/127 [00:24<00:27,  2.42it/s, loss=1.96, v_num=0]
# Epoch 38:  63%|██████▎   | 80/127 [00:33<00:19,  2.42it/s, loss=1.96, v_num=0]
# Epoch 38:  63%|██████▎   | 80/127 [00:33<00:19,  2.42it/s, loss=1.99, v_num=0]
# Epoch 38:  79%|███████▊  | 100/127 [00:41<00:11,  2.42it/s, loss=1.99, v_num=0]
# Epoch 38:  79%|███████▊  | 100/127 [00:41<00:11,  2.42it/s, loss=1.97, v_num=0]
# Epoch 38:  94%|█████████▍| 120/127 [00:49<00:02,  2.41it/s, loss=1.97, v_num=0]
# Epoch 38:  94%|█████████▍| 120/127 [00:49<00:02,  2.41it/s, loss=1.98, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.40it/s]
# Epoch 38: 100%|██████████| 127/127 [00:51<00:00,  2.46it/s, loss=1.98, v_num=0]
# Epoch 38: 100%|██████████| 127/127 [00:51<00:00,  2.46it/s, loss=1.98, v_num=0]
#
#
# Epoch 38: 100%|██████████| 127/127 [00:51<00:00,  2.46it/s, loss=1.98, v_num=0]Epoch 38, global step 4680: 'val/CER' reached 79.44173 (best 79.44173), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/recurrent_rnn_ctc_gpu/checkpoints/epoch=38-step=4680.ckpt' as top 1
#
# Epoch 38:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.98, v_num=0]
# Epoch 39:   0%|          | 0/127 [00:00<?, ?it/s, loss=1.98, v_num=0]
# Epoch 39:  16%|█▌        | 20/127 [00:08<00:45,  2.38it/s, loss=1.98, v_num=0]
# Epoch 39:  16%|█▌        | 20/127 [00:08<00:45,  2.38it/s, loss=1.97, v_num=0]
# Epoch 39:  31%|███▏      | 40/127 [00:16<00:36,  2.41it/s, loss=1.97, v_num=0]
# Epoch 39:  31%|███▏      | 40/127 [00:16<00:36,  2.41it/s, loss=1.96, v_num=0]
# Epoch 39:  47%|████▋     | 60/127 [00:25<00:27,  2.40it/s, loss=1.96, v_num=0]
# Epoch 39:  47%|████▋     | 60/127 [00:25<00:27,  2.40it/s, loss=1.97, v_num=0]
# Epoch 39:  63%|██████▎   | 80/127 [00:33<00:19,  2.39it/s, loss=1.97, v_num=0]
# Epoch 39:  63%|██████▎   | 80/127 [00:33<00:19,  2.39it/s, loss=1.97, v_num=0]
# Epoch 39:  79%|███████▊  | 100/127 [00:41<00:11,  2.40it/s, loss=1.97, v_num=0]
# Epoch 39:  79%|███████▊  | 100/127 [00:41<00:11,  2.40it/s, loss=1.97, v_num=0]
# Epoch 39:  94%|█████████▍| 120/127 [00:49<00:02,  2.40it/s, loss=1.97, v_num=0]
# Epoch 39:  94%|█████████▍| 120/127 [00:49<00:02,  2.40it/s, loss=1.98, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.45it/s]
# Epoch 39: 100%|██████████| 127/127 [00:51<00:00,  2.46it/s, loss=1.98, v_num=0]
# Epoch 39: 100%|██████████| 127/127 [00:51<00:00,  2.46it/s, loss=1.98, v_num=0]
#
#
# Epoch 39: 100%|██████████| 127/127 [00:51<00:00,  2.46it/s, loss=1.98, v_num=0]Epoch 39, global step 4800: 'val/CER' reached 78.86575 (best 78.86575), saving model to '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/recurrent_rnn_ctc_gpu/checkpoints/epoch=39-step=4800.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=40` reached.
#
# Epoch 39: 100%|██████████| 127/127 [00:51<00:00,  2.45it/s, loss=1.98, v_num=0]LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.92it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  3.91it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃  Runningstage.validating  ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/CER          │     78.86575317382812     │
# │          val/DER          │    0.1550731062889099     │
# │          val/IER          │     73.19450378417969     │
# │          val/SER          │     5.516171932220459     │
# │         val/loss          │     1.825974702835083     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 12 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
#
# Testing: 0it [00:00, ?it/s]
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:08<00:00,  8.65s/it]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:08<00:00,  8.66s/it]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/CER          │     80.26799011230469     │
# │         test/DER          │   0.021612275391817093    │
# │         test/IER          │     78.75513458251953     │
# │         test/SER          │    1.4912470579147339     │
# │         test/loss         │    1.6480937004089355     │
# └───────────────────────────┴───────────────────────────┘
# {'val_metrics': [{'val/loss': 1.825974702835083,
#                   'val/CER': 78.86575317382812,
#                   'val/IER': 73.19450378417969,
#                   'val/DER': 0.1550731062889099,
#                   'val/SER': 5.516171932220459}],
#  'test_metrics': [{'test/loss': 1.6480937004089355,
#                    'test/CER': 80.26799011230469,
#                    'test/IER': 78.75513458251953,
#                    'test/DER': 0.021612275391817093,
#                    'test/SER': 1.4912470579147339}],
#  'best_checkpoint': '/content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs/recurrent_rnn_ctc_gpu/checkpoints/epoch=39-step=4800.ckpt'}
# sys:1: DeprecationWarning: builtin type swigvarlink has no __module__ attribute
# recurrent_rnn_ctc completed successfully on gpu in 34.9 min.
#
# All architecture runs completed.

# %%
from pathlib import Path
import pandas as pd
from tensorboard.backend.event_processing import event_accumulator


def latest_scalar(event_file: Path, tag: str):
    ea = event_accumulator.EventAccumulator(str(event_file))
    ea.Reload()
    if tag not in ea.Tags().get('scalars', []):
        return None
    events = ea.Scalars(tag)
    return events[-1].value if events else None


def read_model_name(run_dir: Path) -> str:
    hydra_cfg = run_dir / 'hydra_configs' / 'overrides.yaml'
    if hydra_cfg.exists():
        for line in hydra_cfg.read_text().splitlines():
            if line.startswith('model='):
                return line.split('=', 1)[1]
    name = run_dir.name
    if name.endswith('_gpu'):
        return name[:-4]
    if name.endswith('_cpu'):
        return name[:-4]
    return 'unknown'


runs_root = REPO / 'logs' / 'architecture_experiment' / 'runs'
run_dirs = sorted([p for p in runs_root.glob('*') if p.is_dir()])
print(f'Found {len(run_dirs)} run dirs under {runs_root}')

rows = []
for run_dir in run_dirs:
    event_files = sorted(
        run_dir.glob('lightning_logs/**/events.out.tfevents.*'),
        key=lambda p: p.stat().st_mtime,
    )
    if not event_files:
        continue

    latest_event = event_files[-1]
    model_name = read_model_name(run_dir)

    rows.append(
        {
            'model': model_name,
            'run_dir': str(run_dir),
            'event_file': str(latest_event),
            'val_CER': latest_scalar(latest_event, 'val/CER'),
            'test_CER': latest_scalar(latest_event, 'test/CER'),
            'val_loss': latest_scalar(latest_event, 'val/loss'),
            'test_loss': latest_scalar(latest_event, 'test/loss'),
        }
    )

results_df = pd.DataFrame(rows)
if not results_df.empty:
    results_df = results_df.sort_values('test_CER', na_position='last').reset_index(drop=True)

results_df
# Out:
# Found 3 run dirs under /content/drive/MyDrive/emg2qwerty/logs/architecture_experiment/runs
#                 model                                            run_dir  \
# 0  recurrent_lstm_ctc  /content/drive/MyDrive/emg2qwerty/logs/archite...
# 1        tds_conv_ctc  /content/drive/MyDrive/emg2qwerty/logs/archite...
# 2   recurrent_rnn_ctc  /content/drive/MyDrive/emg2qwerty/logs/archite...
#
#                                           event_file val_CER   test_CER  \
# 0  /content/drive/MyDrive/emg2qwerty/logs/archite...    None  21.698725
# 1  /content/drive/MyDrive/emg2qwerty/logs/archite...    None  25.480873
# 2  /content/drive/MyDrive/emg2qwerty/logs/archite...    None  80.267990
#
#   val_loss  test_loss
# 0     None   0.694346
# 1     None   0.812173
# 2     None   1.648094

# %%
# Save a compact summary CSV for your report.
out_csv = REPO / 'architecture_metrics_summary.csv'
results_df.to_csv(out_csv, index=False)
print('Saved:', out_csv)

# Ranked view by test CER (lower is better)
results_df[['model', 'val_CER', 'test_CER', 'val_loss', 'test_loss']].sort_values('test_CER')
# Out:
# Saved: /content/drive/MyDrive/emg2qwerty/architecture_metrics_summary.csv
#                 model val_CER   test_CER val_loss  test_loss
# 0  recurrent_lstm_ctc    None  21.698725     None   0.694346
# 1        tds_conv_ctc    None  25.480873     None   0.812173
# 2   recurrent_rnn_ctc    None  80.267990     None   1.648094

# %%
import matplotlib.pyplot as plt
import pandas as pd

if results_df.empty:
    print('No results to plot yet. Run training and the metrics cell first.')
else:
    plot_df = results_df.copy()

    plot_df = plot_df.dropna(subset=['model']).sort_values('test_CER', na_position='last')

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    cer_cols = ['val_CER', 'test_CER']
    cer_plot = plot_df.set_index('model')[cer_cols]
    cer_plot.plot(kind='bar', ax=axes[0])
    axes[0].set_title('CER by Architecture')
    axes[0].set_ylabel('CER (%)')
    axes[0].set_xlabel('Model')
    axes[0].grid(axis='y', linestyle='--', alpha=0.3)
    axes[0].legend(loc='upper right')

    loss_cols = ['val_loss', 'test_loss']
    loss_plot = plot_df.set_index('model')[loss_cols]
    loss_plot.plot(kind='bar', ax=axes[1])
    axes[1].set_title('Loss by Architecture')
    axes[1].set_ylabel('Loss')
    axes[1].set_xlabel('Model')
    axes[1].grid(axis='y', linestyle='--', alpha=0.3)
    axes[1].legend(loc='upper right')

    plt.tight_layout()
    plt.show()

    display(plot_df[['model', 'val_CER', 'test_CER', 'val_loss', 'test_loss']])
# Out:
#                 model val_CER   test_CER val_loss  test_loss
# 0  recurrent_lstm_ctc    None  21.698725     None   0.694346
# 1        tds_conv_ctc    None  25.480873     None   0.812173
# 2   recurrent_rnn_ctc    None  80.267990     None   1.648094
